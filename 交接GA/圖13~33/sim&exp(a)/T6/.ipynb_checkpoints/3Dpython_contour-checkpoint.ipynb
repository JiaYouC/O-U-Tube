# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
# 建立 3D 圖形
fig = plt.figure()
#ax = fig.gca(projection='3d')
ax = fig.add_axes(Axes3D(fig))
# 產生 3D 座標資料

x = np.arange(-10,10,0.1)
y = np.arange(-10,10,0.1)
X,Y = np.meshgrid(x,y)
Z=np.add(-np.power(X,3),np.power(Y,2))
# 繪製 3D 座標點

surf = ax.plot_surface(X,Y,Z, cmap=cm.gist_rainbow)
fig.colorbar(surf, shrink=0.5, aspect=50)
# 顯示圖例
#ax.legend()
# 顯示圖形
plt.show()

# %%
from scipy import integrate
import sympy as sy
import math
from csv import reader
from sklearn.metrics import mean_squared_error
from tqdm import trange
#%%
import numba 
from numba import jit
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

with open('CmaCmbT06GPU.csv' , 'r') as csv_file:
        csv_reader = reader(csv_file)
        # Passing the cav_reader object to list() to get a list of lists
        list_of_rows = list(csv_reader)
csv_file.close() 

Cma=np.asarray([x[0] for x in list_of_rows])
Cmb=np.asarray([x[1] for x in list_of_rows],dtype=float)
R100=np.asarray([x[2] for x in list_of_rows],dtype=float)
R200=np.asarray([x[3] for x in list_of_rows],dtype=float)
R300=np.asarray([x[4] for x in list_of_rows],dtype=float)
R400=np.asarray([x[5] for x in list_of_rows],dtype=float)
R500=np.asarray([x[6] for x in list_of_rows],dtype=float)
R600=np.asarray([x[7] for x in list_of_rows],dtype=float)
R700=np.asarray([x[8] for x in list_of_rows],dtype=float)


# 建立 3D 圖形
fig = plt.figure()
#ax = fig.gca(projection='3d')
ax = fig.add_axes(Axes3D(fig))
# 產生 3D 座標資料

x = np.arange(-10,10,0.1)
y = np.arange(-10,10,0.1)
X,Y = np.meshgrid(x,y)
Z=np.add(-np.power(X,3),np.power(Y,2))
# 繪製 3D 座標點

surf = ax.plot_surface(X,Y,Z, cmap=cm.gist_rainbow)
fig.colorbar(surf, shrink=0.5, aspect=50)
# 顯示圖例
#ax.legend()
# 顯示圖形
plt.show()
